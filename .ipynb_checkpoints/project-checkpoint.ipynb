# %% [markdown]
# # Import libraries

# %%
import csv

# %% [markdown]
# # Data Analysis

# %% [markdown]
# # Numpy

# %%
import numpy as np

# %%
with open(r"C:\Users\Kathakoli\Desktop\housing.csv",'r') as f:
    reader = csv.reader(f,delimiter = ',')
    headers = next(reader)
    data = list(reader)
    data = np.array(data)
data
# Out:
# array([['-122.23', '37.88', '41.0', ..., '8.3252', '452600.0',
#         'NEAR BAY'],
#        ['-122.22', '37.86', '21.0', ..., '8.3014', '358500.0',
#         'NEAR BAY'],
#        ['-122.24', '37.85', '52.0', ..., '7.2574', '352100.0',
#         'NEAR BAY'],
#        ...,
#        ['-121.22', '39.43', '17.0', ..., '1.7', '92300.0', 'INLAND'],
#        ['-121.32', '39.43', '18.0', ..., '1.8672', '84700.0', 'INLAND'],
#        ['-121.24', '39.37', '16.0', ..., '2.3886', '89400.0', 'INLAND']],
#       dtype='<U10')

# %%
data[:,0]
# Out:
# array(['-122.23', '-122.22', '-122.24', ..., '-121.22', '-121.32',
#        '-121.24'], dtype='<U10')

# %%
data[2,:]
# Out:
# array(['-122.24', '37.85', '52.0', '1467.0', '190.0', '496.0', '177.0',
#        '7.2574', '352100.0', 'NEAR BAY'], dtype='<U10')

# %%
data.ndim
# Out:
# 2

# %%
data.size
# Out:
# 206400

# %%
x=np.arange(2, 30, 4)
x
# Out:
# array([ 2,  6, 10, 14, 18, 22, 26])

# %%
x.dtype
# dtype of array is int8 (1 byte)
# Out:
# dtype('int32')

# %%
x.itemsize
# Out:
# 4

# %%
x.reshape(7,1)
# Out:
# array([[ 2],
#        [ 6],
#        [10],
#        [14],
#        [18],
#        [22],
#        [26]])

# %%
np.max(x)
# Out:
# 26

# %%
x[3:]
# Out:
# array([14, 18, 22, 26])

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
pip install pandas

# %%
data = np.array(['a','b','c','d'])
s = pd.Series(data)
s
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
data = np.array(['a','b','c','d'])
s = pd.Series(data,index=[100,101,102,103])
s
# Out:
# 100    a
# 101    b
# 102    c
# 103    d
# dtype: object

# %%
s+'20'
# Out:
# 100    a20
# 101    b20
# 102    c20
# 103    d20
# dtype: object

# %%
def concat(s):
    return 'Welcome '+s
s.apply(concat)
# Out:
# 100    Welcome a
# 101    Welcome b
# 102    Welcome c
# 103    Welcome d
# dtype: object

# %%
df=pd.read_csv(r'C:\Users\Kathakoli\Desktop\housing.csv')
df
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# 5        -122.25     37.85                52.0        919.0           213.0
# 6        -122.25     37.84                52.0       2535.0           489.0
# 7        -122.25     37.84                52.0       3104.0           687.0
# 8        -122.26     37.84                42.0       2555.0           665.0
# 9        -122.25     37.84                52.0       3549.0           707.0
# 10       -122.26     37.85                52.0       2202.0           434.0
# ...

# %%
df.shape
# Out:
# (20640, 10)

# %%
df.values
# Out:
# array([[-122.23, 37.88, 41.0, ..., 8.3252, 452600.0, 'NEAR BAY'],
#        [-122.22, 37.86, 21.0, ..., 8.3014, 358500.0, 'NEAR BAY'],
#        [-122.24, 37.85, 52.0, ..., 7.2574, 352100.0, 'NEAR BAY'],
#        ...,
#        [-121.22, 39.43, 17.0, ..., 1.7, 92300.0, 'INLAND'],
#        [-121.32, 39.43, 18.0, ..., 1.8672, 84700.0, 'INLAND'],
#        [-121.24, 39.37, 16.0, ..., 2.3886, 89400.0, 'INLAND']],
#       dtype=object)

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %% [markdown]
# # DATA VISUALISATION

# %% [markdown]
# # Matplotlib

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(range(1,20641),df.iloc[:, 1])
fig = plt.gcf()
fig.set_size_inches(15, 10)

# %%
plt.scatter(df.housing_median_age,df.population, color='Green')
fig = plt.gcf()
fig.set_size_inches(15, 10)

# %%
X=df['ocean_proximity'].value_counts()
X
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
langs = ['<1H OCEAN', 'INLAND', 'NEAR OCEAN ', 'NEAR BAY', 'ISLAND']
ax.pie(X, labels = langs,autopct='%1.2f%%')
plt.show()

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns
from sklearn import datasets

# %%
df1 = sns.load_dataset('iris')
sns.set_style("ticks")
sns.pairplot(df1,hue = 'species',diag_kind = "kde",kind = "scatter",palette = "husl")
plt.show()

# %%
array = [[80, 10],
       [ 4, 49]]
df1_cm = pd.DataFrame(array, index = [i for i in "PN"],
                  columns = [i for i in "PN"])
plt.figure(figsize = (10,7))
sns.heatmap(df1_cm, annot=True)

# %% [markdown]
# # Preprocessing

# %%
X=df[['longitude','latitude','housing_median_age','total_rooms','total_bedrooms','population','households','median_income','median_house_value']]

# %%
div = np.random.rand(len(df)) < 0.8
train = X[div]
test = X[~div]

# %% [markdown]
# class LinearRegression:
#
#   def predict(self, X):
#     return np.dot(X, self._W)
#
#   def _gradient_descent_step(self, X, targets, lr):
#
#     predictions = self.predict(X)
#
#     error = predictions - targets
#     gradient = np.dot(X.T,  error) / len(X)
#
#     self._W -= lr * gradient
#
#   def fit(self, X, y, n_iter=100000, lr=0.01):
#
#     self._W = np.zeros(X.shape[1])
#
#     for i in range(n_iter):
#         self._gradient_descent_step(x, y, lr)
#
#     return self

# %% [markdown]
# # Model

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x = np.asanyarray(train[['median_income']])
train_y = np.asanyarray(train[['median_house_value']])
regr.fit (train_x, train_y)
# Out:
# LinearRegression()

# %%
y1=theta[1]+np.dot(theta[2],X)
J=(1/m)*np.sum((y1-y)**)
for i in range(0,2):
    theta[i]=theta[i]-(alpha*derivative(J,theta[i]))

# %%
plt.scatter(train.median_income, train.median_house_value,  color='blue')
plt.plot(train_x, regr.coef_[0][0]*train_x + regr.intercept_[0], '-r')
fig = plt.gcf()
fig.set_size_inches(15, 10)

# %% [markdown]
# # Prediction

# %%
from sklearn.metrics import r2_score

test_x = np.asanyarray(test[['median_income']])
test_y = np.asanyarray(test[['median_house_value']])
test_y_hat = regr.predict(test_x)
test_y_hat
# Out:
# array([[391882.82441016],
#        [213884.40979106],
#        [198119.74224858],
#        ...,
#        [217565.75391932],
#        [151806.59661678],
#        [152111.28836436]])

# %% [markdown]
# # Evaluation

# %%
print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_hat - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_hat - test_y) ** 2))
print("R2-score: %.2f" % r2_score( test_y, test_y_hat ) )
# Out:
# Mean absolute error: 62199.53
# Residual sum of squares (MSE): 6942143319.51
# R2-score: 0.47

# %% [markdown]
# # Polynomial Regression

# %%
x = np.arange(-5.0, 5.0, 0.1)
y = 2*(x) + 3
y_noise = 2 * np.random.normal(size=x.size)
ydata = y + y_noise
#plt.figure(figsize=(8,6))
plt.plot(x, ydata,  'bo')
plt.plot(x,y, 'r') 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %%
y = 1*(x**3) + 1*(x**2) + 1*x + 3
y_noise = 20 * np.random.normal(size=x.size)
ydata = y + y_noise
plt.plot(x, ydata,  'bo')
plt.plot(x,y, 'r') 
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()
